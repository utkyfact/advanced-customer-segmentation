# %%
import numpy as np
import pandas as pd

# %%
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
# Massachusetts Institute of Technology (MIT) tarafından geliştirilmiş ileri seviye bir kütüphanedir.
# https://anaconda.org/conda-forge/kmodes linkinde detay mevcuttur
# conda install -c conda-forge kmodes   komutu ile Anaconda üzerinde kurabilirsiniz..
from kmodes.kprototypes import KPrototypes  
from kmodes.kmodes import KModes

# %%
df = pd.read_csv("segmentation_data.csv")
df.head()
# Out:
#           ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 0  100000001    0               0   67          2  124670           1
# 1  100000002    1               1   22          1  150773           1
# 2  100000003    0               0   49          1   89210           0
# 3  100000004    0               0   45          1  171565           1
# 4  100000005    0               0   53          1  149031           1
#
#    Settlement size
# 0                2
# 1                2
# 2                0
# 3                1
# 4                1

# %%
df.tail()
# Out:
#              ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 1995  100001996    1               0   47          1  123525           0
# 1996  100001997    1               1   27          1  117744           1
# 1997  100001998    0               0   31          0   86400           0
# 1998  100001999    1               1   24          1   97968           0
# 1999  100002000    0               0   25          0   68416           0
#
#       Settlement size
# 1995                0
# 1996                0
# 1997                0
# 1998                0
# 1999                0

# %%
df.isnull().sum()
# Out:
# ID                 0
# Sex                0
# Marital status     0
# Age                0
# Education          0
# Income             0
# Occupation         0
# Settlement size    0
# dtype: int64

# %%
df_temp = df[['ID','Age', 'Income']]
df_temp
# Out:
#              ID  Age  Income
# 0     100000001   67  124670
# 1     100000002   22  150773
# 2     100000003   49   89210
# 3     100000004   45  171565
# 4     100000005   53  149031
# ...         ...  ...     ...
# 1995  100001996   47  123525
# 1996  100001997   27  117744
# 1997  100001998   31   86400
# 1998  100001999   24   97968
# 1999  100002000   25   68416
#
# [2000 rows x 3 columns]

# %%
scaler = MinMaxScaler()

scaler.fit(df[["Age"]])
df["Age"] = scaler.transform(df[["Age"]])

scaler.fit(df[["Income"]])
df["Income"] = scaler.transform(df[["Income"]])

# %%
df = df.drop(["ID"], axis=1)

# %%
mark_array = df.values

mark_array[:, 2] = mark_array[:, 2].astype(float)
mark_array[:, 4] = mark_array[:, 4].astype(float)

# %%
kproto = KPrototypes(n_clusters=10, verbose=2, max_iter=20)
clusters = kproto.fit_predict(mark_array, categorical=[0,1,3,5,6])

print(kproto.cluster_centroids_)

len(kproto.cluster_centroids_)
# Out:
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/20, moves: 730, ncost: 177.00320562366346
# Run: 1, iteration: 2/20, moves: 145, ncost: 176.4266003338521
# Run: 1, iteration: 3/20, moves: 23, ncost: 176.36023224372684
# Run: 1, iteration: 4/20, moves: 24, ncost: 176.25865632463373
# Run: 1, iteration: 5/20, moves: 16, ncost: 176.2232199867184
# Run: 1, iteration: 6/20, moves: 8, ncost: 176.21267791554743
# Run: 1, iteration: 7/20, moves: 0, ncost: 176.21267791554743
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/20, moves: 855, ncost: 174.02139394343294
# Run: 2, iteration: 2/20, moves: 464, ncost: 164.3928714177929
# Run: 2, iteration: 3/20, moves: 135, ncost: 163.46485601541755
# Run: 2, iteration: 4/20, moves: 25, ncost: 163.29857491148556
# Run: 2, iteration: 5/20, moves: 17, ncost: 163.24611323149662
# Run: 2, iteration: 6/20, moves: 4, ncost: 163.24447312268694
# Run: 2, iteration: 7/20, moves: 1, ncost: 163.2443413312076
# Run: 2, iteration: 8/20, moves: 0, ncost: 163.2443413312076
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/20, moves: 749, ncost: 191.7359496854862
# Run: 3, iteration: 2/20, moves: 269, ncost: 188.08375339601758
# Run: 3, iteration: 3/20, moves: 303, ncost: 169.98314353529466
# Run: 3, iteration: 4/20, moves: 70, ncost: 169.82380799204302
# Run: 3, iteration: 5/20, moves: 16, ncost: 169.79464495170748
# Run: 3, iteration: 6/20, moves: 5, ncost: 169.79000382033118
# Run: 3, iteration: 7/20, moves: 2, ncost: 169.7898668852999
# Run: 3, iteration: 8/20, moves: 0, ncost: 169.7898668852999
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/20, moves: 779, ncost: 187.76398015524924
# Run: 4, iteration: 2/20, moves: 171, ncost: 186.30147184256026
# Run: 4, iteration: 3/20, moves: 57, ncost: 186.10706765561804
# Run: 4, iteration: 4/20, moves: 64, ncost: 185.3192791931016
# Run: 4, iteration: 5/20, moves: 95, ncost: 184.24277248450858
# Run: 4, iteration: 6/20, moves: 53, ncost: 183.97098704842753
# Run: 4, iteration: 7/20, moves: 23, ncost: 183.8959177764001
# Run: 4, iteration: 8/20, moves: 15, ncost: 183.8767102647599
# Run: 4, iteration: 9/20, moves: 9, ncost: 183.86242313492914
# Run: 4, iteration: 10/20, moves: 7, ncost: 183.8479678555309
# Run: 4, iteration: 11/20, moves: 13, ncost: 183.78696819335144
# Run: 4, iteration: 12/20, moves: 6, ncost: 183.77587100791828
# Run: 4, iteration: 13/20, moves: 1, ncost: 183.77573436000046
# Run: 4, iteration: 14/20, moves: 0, ncost: 183.77573436000046
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/20, moves: 701, ncost: 184.84013479787592
# Run: 5, iteration: 2/20, moves: 274, ncost: 168.35217354115937
# Run: 5, iteration: 3/20, moves: 126, ncost: 168.00829274281404
# Run: 5, iteration: 4/20, moves: 160, ncost: 160.0591754328379
# Run: 5, iteration: 5/20, moves: 70, ncost: 159.64669402021278
# Run: 5, iteration: 6/20, moves: 11, ncost: 159.62954163485526
# Run: 5, iteration: 7/20, moves: 6, ncost: 159.62580155716284
# Run: 5, iteration: 8/20, moves: 1, ncost: 159.62564387597806
# Run: 5, iteration: 9/20, moves: 0, ncost: 159.62564387597806
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/20, moves: 844, ncost: 172.71397964957194
# Run: 6, iteration: 2/20, moves: 286, ncost: 165.5431092219794
# Run: 6, iteration: 3/20, moves: 180, ncost: 161.0779891637592
# Run: 6, iteration: 4/20, moves: 65, ncost: 160.89476992835512
# Run: 6, iteration: 5/20, moves: 8, ncost: 160.8798000457624
# Run: 6, iteration: 6/20, moves: 3, ncost: 160.87789207279488
# Run: 6, iteration: 7/20, moves: 0, ncost: 160.87789207279488
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/20, moves: 780, ncost: 169.60988911644748
# Run: 7, iteration: 2/20, moves: 182, ncost: 168.49085700460793
# Run: 7, iteration: 3/20, moves: 55, ncost: 167.94733034484358
# Run: 7, iteration: 4/20, moves: 23, ncost: 167.8603131181982
# Run: 7, iteration: 5/20, moves: 12, ncost: 167.8358899257652
# Run: 7, iteration: 6/20, moves: 3, ncost: 167.83524191331372
# Run: 7, iteration: 7/20, moves: 0, ncost: 167.83524191331372
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/20, moves: 826, ncost: 193.85741976059074
# Run: 8, iteration: 2/20, moves: 109, ncost: 193.49714383432044
# Run: 8, iteration: 3/20, moves: 42, ncost: 193.39689018538144
# Run: 8, iteration: 4/20, moves: 16, ncost: 193.37942309479888
# Run: 8, iteration: 5/20, moves: 9, ncost: 193.36797644185944
# Run: 8, iteration: 6/20, moves: 7, ncost: 193.35626286934354
# Run: 8, iteration: 7/20, moves: 8, ncost: 193.3378419459763
# Run: 8, iteration: 8/20, moves: 7, ncost: 193.32621742887434
# Run: 8, iteration: 9/20, moves: 5, ncost: 193.3220516556947
# Run: 8, iteration: 10/20, moves: 1, ncost: 193.32094225866933
# Run: 8, iteration: 11/20, moves: 0, ncost: 193.32094225866933
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/20, moves: 851, ncost: 185.09508215432797
# Run: 9, iteration: 2/20, moves: 329, ncost: 174.01610833802187
# Run: 9, iteration: 3/20, moves: 118, ncost: 167.7139520244338
# Run: 9, iteration: 4/20, moves: 92, ncost: 166.64273056459666
# Run: 9, iteration: 5/20, moves: 14, ncost: 166.6017200877788
# Run: 9, iteration: 6/20, moves: 11, ncost: 166.57443286419078
# Run: 9, iteration: 7/20, moves: 5, ncost: 166.56392968011525
# Run: 9, iteration: 8/20, moves: 2, ncost: 166.56272819616112
# Run: 9, iteration: 9/20, moves: 0, ncost: 166.56272819616112
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/20, moves: 646, ncost: 182.0167853726074
# Run: 10, iteration: 2/20, moves: 191, ncost: 178.7438162537425
# Run: 10, iteration: 3/20, moves: 70, ncost: 178.4144007040237
# Run: 10, iteration: 4/20, moves: 58, ncost: 178.04951510394756
# Run: 10, iteration: 5/20, moves: 38, ncost: 177.9577422920504
# Run: 10, iteration: 6/20, moves: 14, ncost: 177.9303021557082
# Run: 10, iteration: 7/20, moves: 5, ncost: 177.92444552801607
# Run: 10, iteration: 8/20, moves: 1, ncost: 177.9242829635189
# Run: 10, iteration: 9/20, moves: 0, ncost: 177.9242829635189
# Best run was number 5
# [[0.42429119 0.32872429 0.         0.         1.         1.
#   0.        ]
#  [0.17375411 0.17514659 1.         1.         1.         0.
#   0.        ]
#  [0.16396621 0.28286086 1.         1.         1.         1.
#   0.        ]
#  [0.33438424 0.50632973 0.         0.         1.         2.
#   2.        ]
#  [0.15903563 0.27648043 0.         0.         0.         1.
#   0.        ]
#  [0.76172724 0.47085167 0.         0.         2.         1.
#   1.        ]
#  [0.2275021  0.33718499 0.         1.         1.         1.
#   1.        ]
#  [0.41143007 0.2191487  0.         0.         1.         0.
#   0.        ]
#  [0.17204301 0.32573958 1.         1.         1.         1.
#   1.        ]
#  [0.59365436 0.36609805 1.         1.         2.         1.
#   0.        ]]
# 10

# %%
cluster_dict = []

for c in clusters:
    cluster_dict.append(c)

    
df["cluster"] = cluster_dict

df[["ID","Age","Income"]] = df_temp

# %%
df[df["cluster"]==0].head(10)
# Out:
#     Sex  Marital status  Age  Education  Income  Occupation  Settlement size  \
# 3     0               0   45          1  171565           1                1
# 16    0               0   53          1  125550           1                0
# 20    0               0   48          1  118777           1                1
# 21    0               0   44          1  147511           1                1
# 23    0               0   44          1  134918           1                2
# 37    0               0   37          1  127676           1                1
# 38    0               0   37          1  119276           1                1
# 46    0               0   39          1  140182           1                0
# 61    0               0   50          1  123641           1                1
# 65    0               0   48          1  148115           1                1
#
#     cluster         ID
# 3         0  100000004
# 16        0  100000017
# 20        0  100000021
# 21        0  100000022
# 23        0  100000024
# 37        0  100000038
# 38        0  100000039
# 46        0  100000047
# 61        0  100000062
# 65        0  100000066

# %%
df1 = df[df.cluster==0]
df2 = df[df.cluster==1]
df3 = df[df.cluster==2]
df4 = df[df.cluster==3]
df5 = df[df.cluster==4]
df6 = df[df.cluster==5]
df7 = df[df.cluster==6]
df8 = df[df.cluster==7]
df9 = df[df.cluster==8]
df10 = df[df.cluster==9]

plt.figure(figsize=(15,15))
plt.xlabel('Age')
plt.ylabel('Income')

plt.scatter(df1.Age, df1['Income'],color='green', alpha = 0.4)
plt.scatter(df2.Age, df2['Income'],color='red', alpha = 0.4)
plt.scatter(df3.Age, df3['Income'],color='gray', alpha = 0.4)
plt.scatter(df4.Age, df4['Income'],color='orange', alpha = 0.4)
plt.scatter(df5.Age, df5['Income'],color='yellow', alpha = 0.4)
plt.scatter(df6.Age, df6['Income'],color='cyan', alpha = 0.4)
plt.scatter(df7.Age, df7['Income'],color='magenta', alpha = 0.4)
plt.scatter(df8.Age, df8['Income'],color='gray', alpha = 0.4)
plt.scatter(df9.Age, df9['Income'],color='purple', alpha = 0.4)
plt.scatter(df10.Age, df10['Income'],color='blue', alpha = 0.4)

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
