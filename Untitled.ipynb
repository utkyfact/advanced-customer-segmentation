# %%
import numpy as np
import pandas as pd

# %%
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
from kmodes.kprototypes import KPrototypes  
from kmodes.kmodes import KModes

# %%
df = pd.read_csv("segmentation_data.csv")
df.head()
# Out:
#           ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 0  100000001    0               0   67          2  124670           1
# 1  100000002    1               1   22          1  150773           1
# 2  100000003    0               0   49          1   89210           0
# 3  100000004    0               0   45          1  171565           1
# 4  100000005    0               0   53          1  149031           1
#
#    Settlement size
# 0                2
# 1                2
# 2                0
# 3                1
# 4                1

# %%
df.tail()
# Out:
#              ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 1995  100001996    1               0   47          1  123525           0
# 1996  100001997    1               1   27          1  117744           1
# 1997  100001998    0               0   31          0   86400           0
# 1998  100001999    1               1   24          1   97968           0
# 1999  100002000    0               0   25          0   68416           0
#
#       Settlement size
# 1995                0
# 1996                0
# 1997                0
# 1998                0
# 1999                0

# %%
df.isnull().sum()
# Out:
# ID                 0
# Sex                0
# Marital status     0
# Age                0
# Education          0
# Income             0
# Occupation         0
# Settlement size    0
# dtype: int64

# %%
df_temp = df[['ID','Age', 'Income']]
df_temp
# Out:
#              ID  Age  Income
# 0     100000001   67  124670
# 1     100000002   22  150773
# 2     100000003   49   89210
# 3     100000004   45  171565
# 4     100000005   53  149031
# ...         ...  ...     ...
# 1995  100001996   47  123525
# 1996  100001997   27  117744
# 1997  100001998   31   86400
# 1998  100001999   24   97968
# 1999  100002000   25   68416
#
# [2000 rows x 3 columns]

# %%
scaler = MinMaxScaler()

scaler.fit(df[["Age"]])
df["Age"] = scaler.transform(df[["Age"]])

scaler.fit(df[["Income"]])
df["Income"] = scaler.transform(df[["Income"]])

# %%
df = df.drop(["ID"], axis=1)

# %%
mark_array = df.values

mark_array[:, 2] = mark_array[:, 2].astype(float)
mark_array[:, 4] = mark_array[:, 4].astype(float)

# %%
kproto = KPrototypes(n_clusters=10, verbose=2, max_iter=20)
clusters = kproto.fit_predict(mark_array, categorical=[0,1,3,5,6])

print(kproto.cluster_centroids_)

len(kproto.cluster_centroids_)
# Out:
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/20, moves: 700, ncost: 167.69279802916398
# Run: 1, iteration: 2/20, moves: 237, ncost: 165.59541055036485
# Run: 1, iteration: 3/20, moves: 125, ncost: 159.9479447936193
# Run: 1, iteration: 4/20, moves: 67, ncost: 159.66151562559725
# Run: 1, iteration: 5/20, moves: 18, ncost: 159.64054532092828
# Run: 1, iteration: 6/20, moves: 1, ncost: 159.64048084617934
# Run: 1, iteration: 7/20, moves: 0, ncost: 159.64048084617934
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/20, moves: 766, ncost: 173.72160715884476
# Run: 2, iteration: 2/20, moves: 144, ncost: 173.4097043117416
# Run: 2, iteration: 3/20, moves: 23, ncost: 173.38090644903772
# Run: 2, iteration: 4/20, moves: 20, ncost: 173.36762497771204
# Run: 2, iteration: 5/20, moves: 14, ncost: 173.35727316757308
# Run: 2, iteration: 6/20, moves: 20, ncost: 173.3141168776053
# Run: 2, iteration: 7/20, moves: 56, ncost: 173.02654737652637
# Run: 2, iteration: 8/20, moves: 76, ncost: 172.5538020831617
# Run: 2, iteration: 9/20, moves: 31, ncost: 172.49550638144467
# Run: 2, iteration: 10/20, moves: 13, ncost: 172.48913586760807
# Run: 2, iteration: 11/20, moves: 1, ncost: 172.48871881232395
# Run: 2, iteration: 12/20, moves: 0, ncost: 172.48871881232395
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/20, moves: 664, ncost: 174.8654005640134
# Run: 3, iteration: 2/20, moves: 80, ncost: 174.60511089693028
# Run: 3, iteration: 3/20, moves: 4, ncost: 174.60274245810427
# Run: 3, iteration: 4/20, moves: 2, ncost: 174.60214966828204
# Run: 3, iteration: 5/20, moves: 1, ncost: 174.60143209969897
# Run: 3, iteration: 6/20, moves: 0, ncost: 174.60143209969897
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/20, moves: 783, ncost: 177.0274014388638
# Run: 4, iteration: 2/20, moves: 129, ncost: 176.51190572929815
# Run: 4, iteration: 3/20, moves: 31, ncost: 176.42618684583934
# Run: 4, iteration: 4/20, moves: 7, ncost: 176.40337948982605
# Run: 4, iteration: 5/20, moves: 2, ncost: 176.3961339021959
# Run: 4, iteration: 6/20, moves: 3, ncost: 176.38925258038037
# Run: 4, iteration: 7/20, moves: 0, ncost: 176.38925258038037
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/20, moves: 660, ncost: 193.92744455081618
# Run: 5, iteration: 2/20, moves: 183, ncost: 186.74544295685715
# Run: 5, iteration: 3/20, moves: 98, ncost: 186.05443817073152
# Run: 5, iteration: 4/20, moves: 49, ncost: 185.81012937958482
# Run: 5, iteration: 5/20, moves: 23, ncost: 185.77120001156888
# Run: 5, iteration: 6/20, moves: 8, ncost: 185.76175223559957
# Run: 5, iteration: 7/20, moves: 7, ncost: 185.7556739070251
# Run: 5, iteration: 8/20, moves: 2, ncost: 185.75553038646945
# Run: 5, iteration: 9/20, moves: 0, ncost: 185.75553038646945
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/20, moves: 998, ncost: 185.55964266263743
# Run: 6, iteration: 2/20, moves: 330, ncost: 169.361507815667
# Run: 6, iteration: 3/20, moves: 202, ncost: 168.07447196742046
# Run: 6, iteration: 4/20, moves: 163, ncost: 160.40319264244224
# Run: 6, iteration: 5/20, moves: 49, ncost: 160.21056877796886
# Run: 6, iteration: 6/20, moves: 22, ncost: 160.06013387324055
# Run: 6, iteration: 7/20, moves: 23, ncost: 159.91237529777771
# Run: 6, iteration: 8/20, moves: 9, ncost: 159.89656185663657
# Run: 6, iteration: 9/20, moves: 0, ncost: 159.89656185663657
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/20, moves: 661, ncost: 172.007949517407
# Run: 7, iteration: 2/20, moves: 229, ncost: 170.67933762789926
# Run: 7, iteration: 3/20, moves: 25, ncost: 170.58780076893493
# Run: 7, iteration: 4/20, moves: 10, ncost: 170.57936029271607
# Run: 7, iteration: 5/20, moves: 3, ncost: 170.57799994549066
# Run: 7, iteration: 6/20, moves: 2, ncost: 170.57771318826596
# Run: 7, iteration: 7/20, moves: 1, ncost: 170.57763458805036
# Run: 7, iteration: 8/20, moves: 0, ncost: 170.57763458805036
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/20, moves: 787, ncost: 180.38018123940597
# Run: 8, iteration: 2/20, moves: 326, ncost: 178.1018546850045
# Run: 8, iteration: 3/20, moves: 78, ncost: 177.41081870242536
# Run: 8, iteration: 4/20, moves: 34, ncost: 177.29024282879894
# Run: 8, iteration: 5/20, moves: 45, ncost: 172.88360770918374
# Run: 8, iteration: 6/20, moves: 69, ncost: 172.7112815108251
# Run: 8, iteration: 7/20, moves: 14, ncost: 172.7024603281472
# Run: 8, iteration: 8/20, moves: 2, ncost: 172.70107408939424
# Run: 8, iteration: 9/20, moves: 0, ncost: 172.70107408939424
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/20, moves: 727, ncost: 161.28096212970246
# Run: 9, iteration: 2/20, moves: 89, ncost: 160.92274225450407
# Run: 9, iteration: 3/20, moves: 10, ncost: 160.91667034419476
# Run: 9, iteration: 4/20, moves: 2, ncost: 160.91649056330996
# Run: 9, iteration: 5/20, moves: 0, ncost: 160.91649056330996
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/20, moves: 788, ncost: 179.4049229189653
# Run: 10, iteration: 2/20, moves: 100, ncost: 177.76922603226063
# Run: 10, iteration: 3/20, moves: 53, ncost: 177.59810660170515
# Run: 10, iteration: 4/20, moves: 25, ncost: 177.56851990785526
# Run: 10, iteration: 5/20, moves: 11, ncost: 177.56459399993074
# Run: 10, iteration: 6/20, moves: 2, ncost: 177.56429871454833
# Run: 10, iteration: 7/20, moves: 0, ncost: 177.56429871454833
# Best run was number 1
# [[0.42307098 0.32753259 0.         0.         1.         1.
#   0.        ]
#  [0.17375411 0.17514659 1.         1.         1.         0.
#   0.        ]
#  [0.59729784 0.36736463 1.         1.         2.         1.
#   0.        ]
#  [0.33438424 0.50632973 0.         0.         1.         2.
#   2.        ]
#  [0.15903563 0.27648043 0.         0.         0.         1.
#   0.        ]
#  [0.74879008 0.4673842  0.         0.         2.         1.
#   1.        ]
#  [0.2224245  0.33699063 0.         1.         1.         1.
#   1.        ]
#  [0.41143007 0.2191487  0.         0.         1.         0.
#   0.        ]
#  [0.17204301 0.32573958 1.         1.         1.         1.
#   1.        ]
#  [0.16396621 0.28286086 1.         1.         1.         1.
#   0.        ]]
# 10

# %%
cluster_dict = []

for c in clusters:
    cluster_dict.append(c)

    
df["cluster"] = cluster_dict

df[["ID","Age","Income"]] = df_temp

# %%
df[df["cluster"]==0].head(10)
# Out:
#     Sex  Marital status  Age  Education  Income  Occupation  Settlement size  \
# 3     0               0   45          1  171565           1                1
# 16    0               0   53          1  125550           1                0
# 20    0               0   48          1  118777           1                1
# 21    0               0   44          1  147511           1                1
# 23    0               0   44          1  134918           1                2
# 37    0               0   37          1  127676           1                1
# 38    0               0   37          1  119276           1                1
# 46    0               0   39          1  140182           1                0
# 61    0               0   50          1  123641           1                1
# 65    0               0   48          1  148115           1                1
#
#     cluster         ID
# 3         0  100000004
# 16        0  100000017
# 20        0  100000021
# 21        0  100000022
# 23        0  100000024
# 37        0  100000038
# 38        0  100000039
# 46        0  100000047
# 61        0  100000062
# 65        0  100000066

# %%
df1 = df[df.cluster==0]
df2 = df[df.cluster==1]
df3 = df[df.cluster==2]
df4 = df[df.cluster==3]
df5 = df[df.cluster==4]
df6 = df[df.cluster==5]
df7 = df[df.cluster==6]
df8 = df[df.cluster==7]
df9 = df[df.cluster==8]
df10 = df[df.cluster==9]

plt.figure(figsize=(15,15))
plt.xlabel('Age')
plt.ylabel('Income')

plt.scatter(df1.Age, df1['Income'],color='green', alpha = 0.4)
plt.scatter(df2.Age, df2['Income'],color='red', alpha = 0.4)
plt.scatter(df3.Age, df3['Income'],color='gray', alpha = 0.4)
plt.scatter(df4.Age, df4['Income'],color='orange', alpha = 0.4)
plt.scatter(df5.Age, df5['Income'],color='yellow', alpha = 0.4)
plt.scatter(df6.Age, df6['Income'],color='cyan', alpha = 0.4)
plt.scatter(df7.Age, df7['Income'],color='magenta', alpha = 0.4)
plt.scatter(df8.Age, df8['Income'],color='gray', alpha = 0.4)
plt.scatter(df9.Age, df9['Income'],color='purple', alpha = 0.4)
plt.scatter(df10.Age, df10['Income'],color='blue', alpha = 0.4)

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
